# %%
import pandas as pd
df1 = pd.read_csv('Citywide_Payroll_Data__Fiscal_Year_.csv', low_memory=False)
df1
# Out:
#          Fiscal Year                     Agency Name  Last Name First Name  \
# 0               2016  DISTRICT ATTORNEY-MANHATTAN     ABA'AHMID  RAHASHEEM
# 1               2016  DISTRICT ATTORNEY-MANHATTAN       ABENSUR   MARGARET
# 2               2016  DISTRICT ATTORNEY-MANHATTAN     ABOUNAOUM     ANDREA
# 3               2016  DISTRICT ATTORNEY-MANHATTAN       ABRAHAM   JONATHAN
# 4               2016  DISTRICT ATTORNEY-MANHATTAN        ABRAMS     JOSEPH
# ...              ...                             ...        ...        ...
# 2194483         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194484         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194485         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194486         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194487         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
#
#         Mid Init Agency Start Date Work Location Borough  \
# ...

# %% [markdown]
# # 1 Membuat index

# %%
import numpy as np
import random

# %%
new_index = np.random.randint(0, 100, size = 2194488)

# %%
random.shuffle(new_index)
new_index
# Out:
# array([30, 34, 14, ..., 40, 50, 91])

# %%
df1['Kelompok'] = new_index
df1
# Out:
#           Fiscal Year                     Agency Name   Nama Akhir Nama Awal  \
# Kelompok
# 99               2014  FIRE DEPARTMENT                  DUSHYNSKIY    ANDREW
# 99               2016  DEPT OF ED PER SESSION TEACHER     MARSILLO      ANNA
# 99               2014  DEPT OF ED PEDAGOGICAL               VITOLA  PATRICIA
# 99               2017  DEPT OF ED PEDAGOGICAL                DELEO   MATTHEW
# 99               2015  ADMIN FOR CHILDREN'S SVCS         SANGENITO       IAN
# ...               ...                             ...          ...       ...
# 0                2015  DEPARTMENT OF EDUCATION ADMIN   BUDIYANSKIY      YEVA
# 0                2015  DEPARTMENT OF EDUCATION ADMIN       BUENDIA    ALONSO
# 0                2017  COMMUNITY COLLEGE (MANHATTAN)          STAR   MARRIAH
# 0                2015  DEPARTMENT OF EDUCATION ADMIN        BUHLER      MARK
# 0                2015  DEPT OF ED PARA PROFESSIONALS        IHEBOM  CHIEMEKA
#
# ...

# %%
df1.sort_values('Kelompok', ascending=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11812\688246101.py in ?()
# ----> 1 df1.sort_values('Kelompok', ascending=True)
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1902         axis = self._get_axis_number(axis)
#    1903         other_axes = [ax for ax in range(self._AXIS_LEN) if ax != axis]
#    1904
# ...

# %% [markdown]
# # 2 Set Index

# %%
df1.set_index('Kelompok')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11812\2002798269.py in ?()
# ----> 1 df1.set_index('Kelompok')
#
# C:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    6118                     if not found:
#    6119                         missing.append(col)
#    6120
#    6121         if missing:
# -> 6122             raise KeyError(f"None of {missing} are in the columns")
#    6123
#    6124         if inplace:
#    6125             frame = self
#
# KeyError: "None of ['Kelompok'] are in the columns"

# %%
df1.sort_index()
print(df1.columns)
# Out:
# Index(['Fiscal Year', 'Agency Name', 'Nama Akhir', 'Nama Awal', 'Mid Init',
#        'Agency Start Date', 'Work Location Borough', 'Title Description',
#        'Leave Status as of June 30', 'Base Salary', 'Pay Basis',
#        'Regular Hours', 'Regular Gross Paid', 'OT Hours', 'Total OT Paid',
#        'Total Other Pay', 'Kelompok'],
#       dtype='object')

# %%
df1.sort_index(ascending=False)
# Out:
#           Fiscal Year                     Agency Name   Nama Akhir Nama Awal  \
# Kelompok
# 99               2014  FIRE DEPARTMENT                  DUSHYNSKIY    ANDREW
# 99               2016  DEPT OF ED PER SESSION TEACHER     MARSILLO      ANNA
# 99               2014  DEPT OF ED PEDAGOGICAL               VITOLA  PATRICIA
# 99               2017  DEPT OF ED PEDAGOGICAL                DELEO   MATTHEW
# 99               2015  ADMIN FOR CHILDREN'S SVCS         SANGENITO       IAN
# ...               ...                             ...          ...       ...
# 0                2015  DEPARTMENT OF EDUCATION ADMIN   BUDIYANSKIY      YEVA
# 0                2015  DEPARTMENT OF EDUCATION ADMIN       BUENDIA    ALONSO
# 0                2017  COMMUNITY COLLEGE (MANHATTAN)          STAR   MARRIAH
# 0                2015  DEPARTMENT OF EDUCATION ADMIN        BUHLER      MARK
# 0                2015  DEPT OF ED PARA PROFESSIONALS        IHEBOM  CHIEMEKA
#
# ...

# %% [markdown]
# # 3 Rename

# %%
df1.head()
# Out:
#           Fiscal Year                     Agency Name   Last Name First Name  \
# Kelompok
# 99               2014  FIRE DEPARTMENT                 DUSHYNSKIY     ANDREW
# 99               2016  DEPT OF ED PER SESSION TEACHER    MARSILLO       ANNA
# 99               2014  DEPT OF ED PEDAGOGICAL              VITOLA   PATRICIA
# 99               2017  DEPT OF ED PEDAGOGICAL               DELEO    MATTHEW
# 99               2015  ADMIN FOR CHILDREN'S SVCS        SANGENITO        IAN
#
#          Mid Init Agency Start Date Work Location Borough  \
# Kelompok
# 99            NaN        08/16/2004                   NaN
# 99              M        09/06/2011         MANHATTAN
# 99              A        11/12/1996                   NaN
# 99              F        09/07/1999         MANHATTAN
# 99            NaN        06/05/2000         BROOKLYN
#
#                                           Title Description  \
# Kelompok
# 99        ASSOCIATE FIRE PROTECTION INSPECTOR           ...
# ...

# %%
df1.rename(columns={'Last Name':'Nama Akhir'})
# Out:
#           Fiscal Year                     Agency Name   Nama Akhir First Name  \
# Kelompok
# 99               2014  FIRE DEPARTMENT                  DUSHYNSKIY     ANDREW
# 99               2016  DEPT OF ED PER SESSION TEACHER     MARSILLO       ANNA
# 99               2014  DEPT OF ED PEDAGOGICAL               VITOLA   PATRICIA
# 99               2017  DEPT OF ED PEDAGOGICAL                DELEO    MATTHEW
# 99               2015  ADMIN FOR CHILDREN'S SVCS         SANGENITO        IAN
# ...               ...                             ...          ...        ...
# 0                2015  DEPARTMENT OF EDUCATION ADMIN   BUDIYANSKIY       YEVA
# 0                2015  DEPARTMENT OF EDUCATION ADMIN       BUENDIA     ALONSO
# 0                2017  COMMUNITY COLLEGE (MANHATTAN)          STAR    MARRIAH
# 0                2015  DEPARTMENT OF EDUCATION ADMIN        BUHLER       MARK
# 0                2015  DEPT OF ED PARA PROFESSIONALS        IHEBOM   CHIEMEKA
#
# ...

# %%
df1
# Out:
#           Fiscal Year                     Agency Name    Last Name First Name  \
# Kelompok
# 99               2014  FIRE DEPARTMENT                  DUSHYNSKIY     ANDREW
# 99               2016  DEPT OF ED PER SESSION TEACHER     MARSILLO       ANNA
# 99               2014  DEPT OF ED PEDAGOGICAL               VITOLA   PATRICIA
# 99               2017  DEPT OF ED PEDAGOGICAL                DELEO    MATTHEW
# 99               2015  ADMIN FOR CHILDREN'S SVCS         SANGENITO        IAN
# ...               ...                             ...          ...        ...
# 0                2015  DEPARTMENT OF EDUCATION ADMIN   BUDIYANSKIY       YEVA
# 0                2015  DEPARTMENT OF EDUCATION ADMIN       BUENDIA     ALONSO
# 0                2017  COMMUNITY COLLEGE (MANHATTAN)          STAR    MARRIAH
# 0                2015  DEPARTMENT OF EDUCATION ADMIN        BUHLER       MARK
# 0                2015  DEPT OF ED PARA PROFESSIONALS        IHEBOM   CHIEMEKA
#
# ...

# %%
df1.rename(columns={'First Name':'Nama Awal',
                   'Last Name':'Nama Akhir'})
df1
# Out:
#           Fiscal Year                     Agency Name   Nama Akhir Nama Awal  \
# Kelompok
# 99               2014  FIRE DEPARTMENT                  DUSHYNSKIY    ANDREW
# 99               2016  DEPT OF ED PER SESSION TEACHER     MARSILLO      ANNA
# 99               2014  DEPT OF ED PEDAGOGICAL               VITOLA  PATRICIA
# 99               2017  DEPT OF ED PEDAGOGICAL                DELEO   MATTHEW
# 99               2015  ADMIN FOR CHILDREN'S SVCS         SANGENITO       IAN
# ...               ...                             ...          ...       ...
# 0                2015  DEPARTMENT OF EDUCATION ADMIN   BUDIYANSKIY      YEVA
# 0                2015  DEPARTMENT OF EDUCATION ADMIN       BUENDIA    ALONSO
# 0                2017  COMMUNITY COLLEGE (MANHATTAN)          STAR   MARRIAH
# 0                2015  DEPARTMENT OF EDUCATION ADMIN        BUHLER      MARK
# 0                2015  DEPT OF ED PARA PROFESSIONALS        IHEBOM  CHIEMEKA
#
# ...

# %%
df1.rename(index={0:'A', 1:'B', 2:'C'}, inplace=True)
df1
# Out:
#           Fiscal Year                     Agency Name   Nama Akhir Nama Awal  \
# Kelompok
# 99               2014  FIRE DEPARTMENT                  DUSHYNSKIY    ANDREW
# 99               2016  DEPT OF ED PER SESSION TEACHER     MARSILLO      ANNA
# 99               2014  DEPT OF ED PEDAGOGICAL               VITOLA  PATRICIA
# 99               2017  DEPT OF ED PEDAGOGICAL                DELEO   MATTHEW
# 99               2015  ADMIN FOR CHILDREN'S SVCS         SANGENITO       IAN
# ...               ...                             ...          ...       ...
# A                2015  DEPARTMENT OF EDUCATION ADMIN   BUDIYANSKIY      YEVA
# A                2015  DEPARTMENT OF EDUCATION ADMIN       BUENDIA    ALONSO
# A                2017  COMMUNITY COLLEGE (MANHATTAN)          STAR   MARRIAH
# A                2015  DEPARTMENT OF EDUCATION ADMIN        BUHLER      MARK
# A                2015  DEPT OF ED PARA PROFESSIONALS        IHEBOM  CHIEMEKA
#
# ...
