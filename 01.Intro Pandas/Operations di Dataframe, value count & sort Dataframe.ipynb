# %%
import pandas as pd
df1 = pd.read_csv('Citywide_Payroll_Data__Fiscal_Year_.csv', low_memory=False)
df1
# Out:
#          Fiscal Year                     Agency Name  Last Name First Name  \
# 0               2016  DISTRICT ATTORNEY-MANHATTAN     ABA'AHMID  RAHASHEEM
# 1               2016  DISTRICT ATTORNEY-MANHATTAN       ABENSUR   MARGARET
# 2               2016  DISTRICT ATTORNEY-MANHATTAN     ABOUNAOUM     ANDREA
# 3               2016  DISTRICT ATTORNEY-MANHATTAN       ABRAHAM   JONATHAN
# 4               2016  DISTRICT ATTORNEY-MANHATTAN        ABRAMS     JOSEPH
# ...              ...                             ...        ...        ...
# 2194483         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194484         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194485         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194486         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194487         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
#
#         Mid Init Agency Start Date Work Location Borough  \
# ...

# %% [markdown]
# # 1 Math operation
#
# ## 1.1 Operasi di kolom

# %%
df1['OT Hours'].sum()
# Out:
# 129854142.53000003

# %%
df1['OT Hours'].count()
# Out:
# 2194488

# %%
df1['OT Hours'].mean()
# Out:
# 59.17286516490408

# %%
df1['OT Hours'].std()
# Out:
# 147.92171577476

# %%
df1['OT Hours'].max()
df1['OT Hours'].min()
# Out:
# -27.0

# %%
df1.describe()
# Out:
#         Fiscal Year  Regular Hours      OT Hours
# count  2.194488e+06   2.194488e+06  2.194488e+06
# mean   2.015529e+03   6.660384e+02  5.917287e+01
# std    1.107244e+00   8.876058e+02  1.479217e+02
# min    2.014000e+03  -7.304300e+02 -2.700000e+01
# 25%    2.015000e+03   0.000000e+00  0.000000e+00
# 50%    2.016000e+03   0.000000e+00  0.000000e+00
# 75%    2.017000e+03   1.825000e+03  1.000000e+00
# max    2.017000e+03   4.171430e+03  3.347500e+03

# %% [markdown]
# ## 1.2 Operasi di baris (row)

# %%
# menjumlahkan nilai pada suatu baris
df1['Regular Hours'] + df1['OT Hours']
# Out:
# 0          1832.25
# 1          1831.00
# 2          1182.68
# 3          1831.00
# 4             0.00
#             ...
# 2194483    2164.43
# 2194484    2168.43
# 2194485    2114.43
# 2194486    2073.43
# 2194487    1395.43
# Length: 2194488, dtype: float64

# %%
df1['average'] = (df1['Regular Hours'] + df1['OT Hours'])/2
df1.round(2)
# Out:
#          Fiscal Year                     Agency Name  Last Name First Name  \
# 0               2016  DISTRICT ATTORNEY-MANHATTAN     ABA'AHMID  RAHASHEEM
# 1               2016  DISTRICT ATTORNEY-MANHATTAN       ABENSUR   MARGARET
# 2               2016  DISTRICT ATTORNEY-MANHATTAN     ABOUNAOUM     ANDREA
# 3               2016  DISTRICT ATTORNEY-MANHATTAN       ABRAHAM   JONATHAN
# 4               2016  DISTRICT ATTORNEY-MANHATTAN        ABRAMS     JOSEPH
# ...              ...                             ...        ...        ...
# 2194483         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194484         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194485         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194486         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194487         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
#
#         Mid Init Agency Start Date Work Location Borough  \
# ...

# %% [markdown]
# # 2 Value Count

# %%
# pake function
len(df1['Fiscal Year'])
# pake method
df1['Fiscal Year'].count()
# Out:
# 2194488

# %%
df1['Fiscal Year'].value_counts()
# Out:
# Fiscal Year
# 2015    577880
# 2017    562266
# 2016    544817
# 2014    509525
# Name: count, dtype: int64

# %%
df1['Fiscal Year'].value_counts(normalize=True)
# Out:
# Fiscal Year
# 2015    0.263332
# 2017    0.256217
# 2016    0.248266
# 2014    0.232184
# Name: proportion, dtype: float64

# %%
df1['Fiscal Year'].value_counts(normalize=True).round(2)
# Out:
# Fiscal Year
# 2015    0.26
# 2017    0.26
# 2016    0.25
# 2014    0.23
# Name: proportion, dtype: float64

# %% [markdown]
# # 3 Sort

# %%
df1.sort_values(by='Fiscal Year')
# Out:
#          Fiscal Year                     Agency Name  Last Name First Name  \
# 1232991         2014  COMMUNITY COLLEGE (MANHATTAN)     SPENCER      JERRY
# 1292529         2014  DEPT OF ED PEDAGOGICAL            CROWLEY      KARIN
# 1292530         2014  DEPT OF ED PEDAGOGICAL           DI FIORE     DENISE
# 1292531         2014  DEPT OF ED PEDAGOGICAL          DISTEFANO  CHRISTINE
# 1292532         2014  DEPT OF ED PEDAGOGICAL            EDGHILL    LETICIA
# ...              ...                             ...        ...        ...
# 1819643         2017  DEPT OF ED PARA PROFESSIONALS        MALL     PAMELA
# 1819644         2017  DEPT OF ED PARA PROFESSIONALS     MALLARD     MELVIN
# 1819645         2017  DEPT OF ED PARA PROFESSIONALS    MALLETTE    DESIREE
# 1819639         2017  DEPT OF ED PARA PROFESSIONALS      MALENA   YOBERKIS
# 2194487         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
#
#         Mid Init Agency Start Date Work Location Borough  \
# ...

# %%
df1.sort_values('Fiscal Year', ascending=False)
# jadinya descending kalo value di isi false
# Out:
#          Fiscal Year                     Agency Name Last Name First Name  \
# 2194487         2017  DISTRICT ATTORNEY-SPECIAL NARC       XXX        XXX
# 1819640         2017  DEPT OF ED PARA PROFESSIONALS   MALHOTRA     YOGITA
# 1819646         2017  DEPT OF ED PARA PROFESSIONALS     MALLIA      KATHI
# 1819645         2017  DEPT OF ED PARA PROFESSIONALS   MALLETTE    DESIREE
# 1819644         2017  DEPT OF ED PARA PROFESSIONALS    MALLARD     MELVIN
# ...              ...                             ...       ...        ...
# 1464225         2014  DEPT OF ED PER SESSION TEACHER     YUZUK    KRISTEN
# 1464226         2014  DEPT OF ED PER SESSION TEACHER   ZACKMAN    LINDSAY
# 1464227         2014  DEPT OF ED PER SESSION TEACHER   ZADRIMA     SANDRA
# 1464228         2014  DEPT OF ED PER SESSION TEACHER  ZAKARIAN    DEBORAH
# 1378378         2014  DEPT OF ED PARA PROFESSIONALS      PEPEN   MADELINE
#
#         Mid Init Agency Start Date Work Location Borough  \
# ...

# %%
df1.sort_values(['Fiscal Year', 'Regular Hours'], ascending=False)
# jika 2 atau lebih yang mau diurutkan
# Out:
#          Fiscal Year                     Agency Name  Last Name   First Name  \
# 1729827         2017  DEPARTMENT OF CORRECTION          JOHNSON        DAVID
# 2096408         2017  HRA/DEPT OF SOCIAL SERVICES       KASSNER      RICHARD
# 2096605         2017  HRA/DEPT OF SOCIAL SERVICES         KLEIN        DAVID
# 2028184         2017  DEPT OF ENVIRONMENT PROTECTION      ADAMS        SHAUN
# 2028244         2017  DEPT OF ENVIRONMENT PROTECTION      ALANA         ALEX
# ...              ...                             ...        ...          ...
# 1598655         2014               Police Department     KOZLOW        DAVID
# 1122731         2014  OFFICE OF THE MAYOR             SOTOLONGO        GRACE
# 1570435         2014  NYC HOUSING AUTHORITY           ETHERIDGE      LAKISHA
# 1573189         2014               Police Department       AMOS        HENRY
# 1135210         2014  FIRE DEPARTMENT                   MAHONEY  CHRISTOPHER
#
# ...

# %%
df1.sort_values(['Fiscal Year', 'Regular Hours'], ascending=False, inplace=True)

# %%
df1
# Out:
#          Fiscal Year                     Agency Name  Last Name   First Name  \
# 1729827         2017  DEPARTMENT OF CORRECTION          JOHNSON        DAVID
# 2096408         2017  HRA/DEPT OF SOCIAL SERVICES       KASSNER      RICHARD
# 2096605         2017  HRA/DEPT OF SOCIAL SERVICES         KLEIN        DAVID
# 2028184         2017  DEPT OF ENVIRONMENT PROTECTION      ADAMS        SHAUN
# 2028244         2017  DEPT OF ENVIRONMENT PROTECTION      ALANA         ALEX
# ...              ...                             ...        ...          ...
# 1598655         2014               Police Department     KOZLOW        DAVID
# 1122731         2014  OFFICE OF THE MAYOR             SOTOLONGO        GRACE
# 1570435         2014  NYC HOUSING AUTHORITY           ETHERIDGE      LAKISHA
# 1573189         2014               Police Department       AMOS        HENRY
# 1135210         2014  FIRE DEPARTMENT                   MAHONEY  CHRISTOPHER
#
# ...

# %%
# sort dengan key function untuk mengabaikan lower case dan upper case
df1.sort_values('First Name', ascending = True, key=lambda col:col.str.lower())
# Out:
#          Fiscal Year                     Agency Name        Last Name  \
# 1701443         2017  COMMUNITY COLLEGE (LAGUARDIA)   MIDDLETON CHIOD
# 1039669         2015  DEPT OF PARKS & RECREATION               GUZMAN
# 1054385         2015  DEPT OF PARKS & RECREATION             WILLIAMS
# 1032241         2015  DEPT OF PARKS & RECREATION                BEANE
# 2050229         2017  DEPT OF PARKS & RECREATION               HARRIS
# ...              ...                             ...              ...
# 1630926         2014                 Manhattan DA                 NaN
# 1629302         2014                     Queens DA                NaN
# 1238889         2014  COMMUNITY COLLEGE (HOSTOS)                   XU
# 1629290         2014                     Queens DA                NaN
# 1411444         2014  DEPT OF ED PER DIEM TEACHERS                SHA
#
#         First Name Mid Init Agency Start Date Work Location Borough  \
# ...
