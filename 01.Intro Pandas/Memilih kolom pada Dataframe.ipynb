# %%
import pandas as pd

# %%
df1 = pd.read_csv('Citywide_Payroll_Data__Fiscal_Year_.csv', low_memory=False)
df1
# Out:
#          Fiscal Year                     Agency Name  Last Name First Name  \
# 0               2016  DISTRICT ATTORNEY-MANHATTAN     ABA'AHMID  RAHASHEEM
# 1               2016  DISTRICT ATTORNEY-MANHATTAN       ABENSUR   MARGARET
# 2               2016  DISTRICT ATTORNEY-MANHATTAN     ABOUNAOUM     ANDREA
# 3               2016  DISTRICT ATTORNEY-MANHATTAN       ABRAHAM   JONATHAN
# 4               2016  DISTRICT ATTORNEY-MANHATTAN        ABRAMS     JOSEPH
# ...              ...                             ...        ...        ...
# 2194483         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194484         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194485         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194486         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194487         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
#
#         Mid Init Agency Start Date Work Location Borough  \
# ...

# %% [markdown]
# # 1 Memilih satu Kolom

# %%
df1 ['Mid Init']
# Out:
# 0            E
# 1          NaN
# 2            L
# 3            J
# 4          NaN
#           ...
# 2194483      G
# 2194484      C
# 2194485    NaN
# 2194486      J
# 2194487      L
# Name: Mid Init, Length: 2194488, dtype: object

# %%
type(df1['Mid Init'])
# Out:
# pandas.core.series.Series

# %%
(df1['Mid Init']).index
(df1['Mid Init']).head()
# Out:
# 0      E
# 1    NaN
# 2      L
# 3      J
# 4    NaN
# Name: Mid Init, dtype: object

# %% [markdown]
# ## 1.2 s2

# %%
df1['Mid Init']
# Out:
# 0            E
# 1          NaN
# 2            L
# 3            J
# 4          NaN
#           ...
# 2194483      G
# 2194484      C
# 2194485    NaN
# 2194486      J
# 2194487      L
# Name: Mid Init, Length: 2194488, dtype: object

# %% [markdown]
# ## 2 memilih dua kolom

# %%
df1[['Last Name', 'First Name']]
# Out:
#          Last Name First Name
# 0        ABA'AHMID  RAHASHEEM
# 1          ABENSUR   MARGARET
# 2        ABOUNAOUM     ANDREA
# 3          ABRAHAM   JONATHAN
# 4           ABRAMS     JOSEPH
# ...            ...        ...
# 2194483        XXX        XXX
# 2194484        XXX        XXX
# 2194485        XXX        XXX
# 2194486        XXX        XXX
# 2194487        XXX        XXX
#
# [2194488 rows x 2 columns]

# %%
type(df1[['Last Name', 'First Name']])
# [] = series
# [[]] = Dataframe
# Out:
# pandas.core.frame.DataFrame

# %%
df1[[ 'First Name','Last Name','Base Salary','Pay Basis']]
# Out:
#         First Name  Last Name Base Salary   Pay Basis
# 0        RAHASHEEM  ABA'AHMID   $47678.00   per Annum
# 1         MARGARET    ABENSUR  $119959.00   per Annum
# 2           ANDREA  ABOUNAOUM   $39966.00   per Annum
# 3         JONATHAN    ABRAHAM  $116000.00   per Annum
# 4           JOSEPH     ABRAMS       $1.00    per Hour
# ...            ...        ...         ...         ...
# 2194483        XXX        XXX   $80643.00   per Annum
# 2194484        XXX        XXX   $88883.00   per Annum
# 2194485        XXX        XXX   $89686.00   per Annum
# 2194486        XXX        XXX   $94245.00   per Annum
# 2194487        XXX        XXX   $89780.00   per Annum
#
# [2194488 rows x 4 columns]
