# %%
import pandas as pd

# %%
df1 = pd.read_csv('Citywide_Payroll_Data__Fiscal_Year_.csv', low_memory = False)
df1
# Out:
#          Fiscal Year                     Agency Name  Last Name First Name  \
# 0               2016  DISTRICT ATTORNEY-MANHATTAN     ABA'AHMID  RAHASHEEM
# 1               2016  DISTRICT ATTORNEY-MANHATTAN       ABENSUR   MARGARET
# 2               2016  DISTRICT ATTORNEY-MANHATTAN     ABOUNAOUM     ANDREA
# 3               2016  DISTRICT ATTORNEY-MANHATTAN       ABRAHAM   JONATHAN
# 4               2016  DISTRICT ATTORNEY-MANHATTAN        ABRAMS     JOSEPH
# ...              ...                             ...        ...        ...
# 2194483         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194484         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194485         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194486         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194487         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
#
#         Mid Init Agency Start Date Work Location Borough  \
# ...

# %%
# nambahin kolom baru, jangan di run
df1['Orang kaya'] = iya

# %% [markdown]
# ## 1.2 dengan array

# %%
import numpy as np

# %%
tes = np.arange(0, 2194488)

# %%
# nambahinnya tapi ini bedanya sequence, jangan di run
df1['Orang kaya'] = tes

# %%
# random integer
rand = np.random.randint(1, 100, size = 10)
rand
# Out:
# array([84, 88, 51, 92, 30, 75, 48, 90, 38, 69])

# %%
# random float
rand1 = np.random.uniform(1,100, size = 10)
rand1
# Out:
# array([59.73430467, 61.77386178, 67.07265972, 94.89708203, 93.97338797,
#         8.32389796, 99.28651393, 81.98896416, 17.92494708, 43.10699448])

# %% [markdown]
# # 2 Kolom baru dengan cara assign() dan insert()
#
# Assign digunakan saat:
#     - ingin menambahkan beberapa kolom di satu line kode
#     - ketika ingin mengubah value dari kolom yang sudah ada
# nanti akan mengembalikan objek baru dengan semua kolom original ke yang baru

# %%
df1['score1'] = 70

# %%
df1
# Out:
#          Fiscal Year                     Agency Name  Last Name First Name  \
# 0               2016  DISTRICT ATTORNEY-MANHATTAN     ABA'AHMID  RAHASHEEM
# 1               2016  DISTRICT ATTORNEY-MANHATTAN       ABENSUR   MARGARET
# 2               2016  DISTRICT ATTORNEY-MANHATTAN     ABOUNAOUM     ANDREA
# 3               2016  DISTRICT ATTORNEY-MANHATTAN       ABRAHAM   JONATHAN
# 4               2016  DISTRICT ATTORNEY-MANHATTAN        ABRAMS     JOSEPH
# ...              ...                             ...        ...        ...
# 2194483         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194484         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194485         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194486         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194487         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
#
#         Mid Init Agency Start Date Work Location Borough  \
# ...

# %%
score1 = np.random.randint(1,100, size=2194488)

# %%
series1 = pd.Series(score1, index=np.arange(0, 2194488))

# %%
df1 = df1.assign(score1 = series1)

# %%
df1
# Out:
#          Fiscal Year                     Agency Name  Last Name First Name  \
# 0               2016  DISTRICT ATTORNEY-MANHATTAN     ABA'AHMID  RAHASHEEM
# 1               2016  DISTRICT ATTORNEY-MANHATTAN       ABENSUR   MARGARET
# 2               2016  DISTRICT ATTORNEY-MANHATTAN     ABOUNAOUM     ANDREA
# 3               2016  DISTRICT ATTORNEY-MANHATTAN       ABRAHAM   JONATHAN
# 4               2016  DISTRICT ATTORNEY-MANHATTAN        ABRAMS     JOSEPH
# ...              ...                             ...        ...        ...
# 2194483         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194484         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194485         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194486         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194487         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
#
#         Mid Init Agency Start Date Work Location Borough  \
# ...

# %%
df1.insert(1, 'score2', series1)

# %%
df1
# Out:
#          Fiscal Year  score2                     Agency Name  Last Name  \
# 0               2016      48  DISTRICT ATTORNEY-MANHATTAN     ABA'AHMID
# 1               2016      49  DISTRICT ATTORNEY-MANHATTAN       ABENSUR
# 2               2016      22  DISTRICT ATTORNEY-MANHATTAN     ABOUNAOUM
# 3               2016      27  DISTRICT ATTORNEY-MANHATTAN       ABRAHAM
# 4               2016       8  DISTRICT ATTORNEY-MANHATTAN        ABRAMS
# ...              ...     ...                             ...        ...
# 2194483         2017      60  DISTRICT ATTORNEY-SPECIAL NARC        XXX
# 2194484         2017      95  DISTRICT ATTORNEY-SPECIAL NARC        XXX
# 2194485         2017      44  DISTRICT ATTORNEY-SPECIAL NARC        XXX
# 2194486         2017      98  DISTRICT ATTORNEY-SPECIAL NARC        XXX
# 2194487         2017      91  DISTRICT ATTORNEY-SPECIAL NARC        XXX
#
#         First Name Mid Init Agency Start Date Work Location Borough  \
# ...
