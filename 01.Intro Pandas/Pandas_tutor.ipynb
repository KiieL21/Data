# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # 1 Array
# ## 1.1 opsi 1

# %%
data = np.array([[1,4], [6,6], [6,3]])
data
# Out:
# array([[1, 4],
#        [6, 6],
#        [6, 3]])

# %%
df = pd.DataFrame(data, index=['row 1', 2, 3], 
                 columns=['col1', 'col2'])
df
# Out:
#        col1  col2
# row 1     1     4
# 2         6     6
# 3         6     3

# %% [markdown]
# # 1.2 opsi 2

# %%
# array tapi pake bentuk list
data = [[1,4], [6,6], [7,1]]
data
# Out:
# [[1, 4], [6, 6], [7, 1]]

# %%
df = pd.DataFrame(data, index=['row 1', 2, 3], 
                 columns=['col1', 'col2'])
df
# Out:
#        col1  col2
# row 1     1     4
# 2         6     6
# 3         7     1

# %% [markdown]
# # 2 Membuat DataFrame dari dict

# %%
import pandas as pd

# %%
# buka file csv
tes = pd.read_csv('Citywide_Payroll_Data__Fiscal_Year_.csv')
tes
# Out:
# C:\Users\fahri\AppData\Local\Temp\ipykernel_21784\2166460461.py:2: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   tes = pd.read_csv('Citywide_Payroll_Data__Fiscal_Year_.csv')
#          Fiscal Year                     Agency Name  Last Name First Name  \
# 0               2016  DISTRICT ATTORNEY-MANHATTAN     ABA'AHMID  RAHASHEEM
# 1               2016  DISTRICT ATTORNEY-MANHATTAN       ABENSUR   MARGARET
# 2               2016  DISTRICT ATTORNEY-MANHATTAN     ABOUNAOUM     ANDREA
# 3               2016  DISTRICT ATTORNEY-MANHATTAN       ABRAHAM   JONATHAN
# 4               2016  DISTRICT ATTORNEY-MANHATTAN        ABRAMS     JOSEPH
# ...              ...                             ...        ...        ...
# 2194483         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194484         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# ...

# %%
tes.head()
# Out:
#    Fiscal Year                     Agency Name  Last Name First Name Mid Init  \
# 0         2016  DISTRICT ATTORNEY-MANHATTAN     ABA'AHMID  RAHASHEEM        E
# 1         2016  DISTRICT ATTORNEY-MANHATTAN       ABENSUR   MARGARET      NaN
# 2         2016  DISTRICT ATTORNEY-MANHATTAN     ABOUNAOUM     ANDREA        L
# 3         2016  DISTRICT ATTORNEY-MANHATTAN       ABRAHAM   JONATHAN        J
# 4         2016  DISTRICT ATTORNEY-MANHATTAN        ABRAMS     JOSEPH      NaN
#
#   Agency Start Date Work Location Borough  \
# 0        07/14/2003         MANHATTAN
# 1        06/12/1995         MANHATTAN
# 2        10/11/2011         MANHATTAN
# 3        12/01/2014         MANHATTAN
# 4        05/21/2015         MANHATTAN
#
#                                    Title Description  \
# 0  COMMUNITY ASSOCIATE                           ...
# 1  ADMINISTRATIVE ACCOUNTANT                     ...
# 2  COMMUNITY ASSOCIATE                           ...
# ...

# %%
tes.tail()
# Out:
#          Fiscal Year                     Agency Name Last Name First Name  \
# 2194483         2017  DISTRICT ATTORNEY-SPECIAL NARC       XXX        XXX
# 2194484         2017  DISTRICT ATTORNEY-SPECIAL NARC       XXX        XXX
# 2194485         2017  DISTRICT ATTORNEY-SPECIAL NARC       XXX        XXX
# 2194486         2017  DISTRICT ATTORNEY-SPECIAL NARC       XXX        XXX
# 2194487         2017  DISTRICT ATTORNEY-SPECIAL NARC       XXX        XXX
#
#         Mid Init Agency Start Date Work Location Borough  \
# 2194483        G        10/02/2006         MANHATTAN
# 2194484        C        01/18/2000         MANHATTAN
# 2194485      NaN        03/17/1997         MANHATTAN
# 2194486        J        04/19/1993         MANHATTAN
# 2194487        L        02/10/1992         MANHATTAN
#
#                              Title Description Leave Status as of June 30  \
# 2194483  SUPERVISING RACKETS INVESTIGATOR                          ACTIVE
# ...

# %%
tes.head(10)
# Out:
#    Fiscal Year                     Agency Name  Last Name First Name Mid Init  \
# 0         2016  DISTRICT ATTORNEY-MANHATTAN     ABA'AHMID  RAHASHEEM        E
# 1         2016  DISTRICT ATTORNEY-MANHATTAN       ABENSUR   MARGARET      NaN
# 2         2016  DISTRICT ATTORNEY-MANHATTAN     ABOUNAOUM     ANDREA        L
# 3         2016  DISTRICT ATTORNEY-MANHATTAN       ABRAHAM   JONATHAN        J
# 4         2016  DISTRICT ATTORNEY-MANHATTAN        ABRAMS     JOSEPH      NaN
# 5         2016  DISTRICT ATTORNEY-MANHATTAN         ABREU   JENNIFER      NaN
# 6         2016  DISTRICT ATTORNEY-MANHATTAN         ABREU       JUAN        D
# 7         2016  DISTRICT ATTORNEY-MANHATTAN       ACEVEDO   JENNIFER      NaN
# 8         2016  DISTRICT ATTORNEY-MANHATTAN      ACOCELLA    MATTHEW        J
# 9         2016  DISTRICT ATTORNEY-MANHATTAN        ACOSTA       RITA        E
#
#   Agency Start Date Work Location Borough  \
# 0        07/14/2003         MANHATTAN
# ...

# %%
tes.tail(10)
# Out:
#          Fiscal Year                     Agency Name Last Name First Name  \
# 2194478         2017  DISTRICT ATTORNEY-SPECIAL NARC       XXX        XXX
# 2194479         2017  DISTRICT ATTORNEY-SPECIAL NARC       XXX        XXX
# 2194480         2017  DISTRICT ATTORNEY-SPECIAL NARC       XXX        XXX
# 2194481         2017  DISTRICT ATTORNEY-SPECIAL NARC       XXX        XXX
# 2194482         2017  DISTRICT ATTORNEY-SPECIAL NARC   BRENNAN    BRIDGET
# 2194483         2017  DISTRICT ATTORNEY-SPECIAL NARC       XXX        XXX
# 2194484         2017  DISTRICT ATTORNEY-SPECIAL NARC       XXX        XXX
# 2194485         2017  DISTRICT ATTORNEY-SPECIAL NARC       XXX        XXX
# 2194486         2017  DISTRICT ATTORNEY-SPECIAL NARC       XXX        XXX
# 2194487         2017  DISTRICT ATTORNEY-SPECIAL NARC       XXX        XXX
#
#         Mid Init Agency Start Date Work Location Borough  \
# 2194478      NaN        02/28/1994         MANHATTAN
# ...

# %%
tes.shape
# Out:
# (2194488, 16)

# %%
pd.set_option('display.max_rows', 200)

# %%
tes
# Out:
#          Fiscal Year                     Agency Name  Last Name First Name  \
# 0               2016  DISTRICT ATTORNEY-MANHATTAN     ABA'AHMID  RAHASHEEM
# 1               2016  DISTRICT ATTORNEY-MANHATTAN       ABENSUR   MARGARET
# 2               2016  DISTRICT ATTORNEY-MANHATTAN     ABOUNAOUM     ANDREA
# 3               2016  DISTRICT ATTORNEY-MANHATTAN       ABRAHAM   JONATHAN
# 4               2016  DISTRICT ATTORNEY-MANHATTAN        ABRAMS     JOSEPH
# ...              ...                             ...        ...        ...
# 2194483         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194484         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194485         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194486         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
# 2194487         2017  DISTRICT ATTORNEY-SPECIAL NARC        XXX        XXX
#
#         Mid Init Agency Start Date Work Location Borough  \
# ...
